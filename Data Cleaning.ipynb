# %%
import pandas as pd
import numpy as np
import os
from libraries import hide_toggle

# %% [markdown]
# # Tables des matières
#
# # 1. Selection de la population et des individus
# # 2. Sélection des attributs avec la méthode PESTEL
#    **2.1** [Croissance démographique moyenne](#21)
#    **2.2** [Stabilité politique moyenne (2000-2018)](#22)
#    2.3 [Evolution du PIB moyen (1961 - 2021)](#23)
#    2.4 [Les écarts moyen sur le revenu des ménages (1960 - 2021)](#24)
#    2.5 [Les emissions de CO2 (1960 - 2018)](#25)
#    2.6 [Les décès liés à la sous-nutrition (1960 - 2021)](#26)

# %%
main_data = pd.read_csv("Data Source/DisponibiliteAlimentaire_2017.csv")

# %%
main_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176600 entries, 0 to 176599
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Code Domaine            176600 non-null  object
#  1   Domaine                 176600 non-null  object
#  2   Code zone               176600 non-null  int64
#  3   Zone                    176600 non-null  object
#  4   Code Élément            176600 non-null  int64
#  5   Élément                 176600 non-null  object
#  6   Code Produit            176600 non-null  int64
#  7   Produit                 176600 non-null  object
#  8   Code année              176600 non-null  int64
#  9   Année                   176600 non-null  int64
#  10  Unité                   176600 non-null  object
#  11  Valeur                  176600 non-null  float64
#  12  Symbole                 176600 non-null  object
#  13  Description du Symbole  176600 non-null  object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 18.9+ MB

# %%
main_data.head(5)
# Out:
#   Code Domaine                      Domaine  Code zone         Zone  \
# 0          FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 1          FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 2          FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 3          FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
# 4          FBS  Nouveaux Bilans Alimentaire          2  Afghanistan
#
#    Code Élément                   Élément  Code Produit          Produit  \
# 0          5511                Production          2511  Blé et produits
# 1          5611   Importations - Quantité          2511  Blé et produits
# 2          5072        Variation de stock          2511  Blé et produits
# 3          5911   Exportations - Quantité          2511  Blé et produits
# 4          5301  Disponibilité intérieure          2511  Blé et produits
#
#    Code année  Année               Unité  Valeur Symbole  \
# 0        2017   2017  Milliers de tonnes  4281.0       S
# 1        2017   2017  Milliers de tonnes  2302.0       S
# 2        2017   2017  Milliers de tonnes  -119.0       S
# 3        2017   2017  Milliers de tonnes     0.0       S
# 4        2017   2017  Milliers de tonnes  6701.0       S
#
#   Description du Symbole
# 0  Données standardisées
# 1  Données standardisées
# 2  Données standardisées
# 3  Données standardisées
# 4  Données standardisées

# %%
rm_columns=["Code Domaine","Domaine","Code zone","Code Élément","Code Produit","Code année","Description du Symbole","Symbole"]
main_data.drop(columns=rm_columns, inplace=True)

# %%
main_data.isna().sum()
# Out:
# Zone       0
# Élément    0
# Produit    0
# Année      0
# Unité      0
# Valeur     0
# dtype: int64

# %% [markdown]
# ## Selection de la population et des individus

# %%
main_data["Produit"].unique()
# Out:
# array(['Blé et produits', 'Riz et produits', 'Orge et produits',
#        'Maïs et produits', 'Seigle et produits', 'Avoine',
#        'Millet et produits', 'Sorgho et produits', 'Céréales, Autres',
#        'Pommes de Terre et produits', 'Ignames', 'Racines nda',
#        'Sucre, canne', 'Sucre, betterave', 'Sucre Eq Brut',
#        'Edulcorants Autres', 'Miel', 'Haricots', 'Pois',
#        'Légumineuses Autres et produits', 'Noix et produits', 'Soja',
#        'Arachides Decortiquees', 'Graines de tournesol',
#        'Graines Colza/Moutarde', 'Graines de coton', 'Coco (Incl Coprah)',
#        'Sésame', 'Olives', 'Plantes Oleiferes, Autre', 'Huile de Soja',
#        "Huile d'Arachide", 'Huile de Tournesol',
#        'Huile de Colza&Moutarde', 'Huile Graines de Coton',
#        'Huile de Palmistes', 'Huile de Palme', 'Huile de Coco',
#        'Huile de Sésame', "Huile d'Olive", 'Huile de Son de Riz',
#        'Huile de Germe de Maïs', 'Huil Plantes Oleif Autr',
#        'Tomates et produits', 'Oignons', 'Légumes, Autres',
#        'Oranges, Mandarines', 'Citrons & Limes et produits',
#        'Pamplemousse et produits', 'Agrumes, Autres', 'Bananes',
#        'Pommes et produits', 'Ananas et produits', 'Dattes', 'Raisin',
#        'Fruits, Autres', 'Café et produits', 'Feve de Cacao et produits',
#        'Thé', 'Poivre', 'Piments', 'Girofles', 'Épices, Autres', 'Vin',
#        'Bière', 'Boissons Fermentés', 'Boissons Alcooliques',
#        'Alcool, non Comestible', 'Viande de Bovins',
#        "Viande d'Ovins/Caprins", 'Viande de Suides',
#        'Viande de Volailles', 'Viande, Autre', 'Abats Comestible',
#        'Beurre, Ghee', 'Crème', 'Graisses Animales Crue', 'Oeufs',
#        'Lait - Excl Beurre', 'Poissons Eau Douce',
#        'Aliments pour enfants', 'Miscellanees', 'Manioc et produits',
#        'Patates douces', 'Palmistes', 'Bananes plantains',
#        'Huiles de Poissons', 'Huiles de Foie de Poisso', 'Perciform',
#        'Poissons Pelagiques', 'Poissons Marins, Autres', 'Crustacés',
#        'Cephalopodes', 'Mollusques, Autres', 'Animaux Aquatiques Autre',
#        'Plantes Aquatiques', 'Sucre non centrifugé',
#        'Viande de Anim Aquatiq'], dtype=object)

# %%
# On récupère les données ciblées sur le poulet
volaille_data = main_data.loc[main_data["Produit"] == "Viande de Volailles", :]

# %%
# Création des variables quantitatives
volaille_data = pd.pivot_table(volaille_data, index=["Zone","Année"], columns="Élément")

# %%
volaille_data[("Valeur")].columns
# Out:
# Index(['Alimentation pour touristes', 'Aliments pour animaux',
#        'Autres utilisations (non alimentaire)',
#        'Disponibilité alimentaire (Kcal/personne/jour)',
#        'Disponibilité alimentaire en quantité (kg/personne/an)',
#        'Disponibilité de matière grasse en quantité (g/personne/jour)',
#        'Disponibilité de protéines en quantité (g/personne/jour)',
#        'Disponibilité intérieure', 'Exportations - Quantité',
#        'Importations - Quantité', 'Nourriture', 'Pertes', 'Production',
#        'Résidus', 'Semences', 'Traitement', 'Variation de stock'],
#       dtype='object', name='Élément')

# %%
volaille_data["Valeur"].isna().sum()
# Out:
# Élément
# Alimentation pour touristes                                       94
# Aliments pour animaux                                            171
# Autres utilisations (non alimentaire)                            138
# Disponibilité alimentaire (Kcal/personne/jour)                     0
# Disponibilité alimentaire en quantité (kg/personne/an)             0
# Disponibilité de matière grasse en quantité (g/personne/jour)      0
# Disponibilité de protéines en quantité (g/personne/jour)           0
# Disponibilité intérieure                                           2
# Exportations - Quantité                                           37
# Importations - Quantité                                            2
# Nourriture                                                         2
# Pertes                                                           105
# Production                                                         4
# Résidus                                                            8
# Semences                                                         171
# Traitement                                                       126
# Variation de stock                                                 3
# dtype: int64

# %%
volaille_data=volaille_data["Valeur"].reset_index()

# %%
# Réduction de dimension grâce aux valeurs nulles et manquantes
rm_columns = ["Pertes","Semences","Résidus","Traitement","Variation de stock","Aliments pour animaux",
              "Autres utilisations (non alimentaire)","Alimentation pour touristes"]

# %%
volaille_data.drop(columns=rm_columns, inplace=True)

# %%
volaille_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172 entries, 0 to 171
# Data columns (total 11 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Zone                                                           172 non-null    object
#  1   Année                                                          172 non-null    int64
#  2   Disponibilité alimentaire (Kcal/personne/jour)                 172 non-null    float64
#  3   Disponibilité alimentaire en quantité (kg/personne/an)         172 non-null    float64
#  4   Disponibilité de matière grasse en quantité (g/personne/jour)  172 non-null    float64
#  5   Disponibilité de protéines en quantité (g/personne/jour)       172 non-null    float64
#  6   Disponibilité intérieure                                       170 non-null    float64
#  7   Exportations - Quantité                                        135 non-null    float64
#  8   Importations - Quantité                                        170 non-null    float64
#  9   Nourriture                                                     170 non-null    float64
#  10  Production                                                     168 non-null    float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 14.9+ KB

# %%
volaille_data.head()
# Out:
# Élément            Zone  Année  \
# 0           Afghanistan   2017
# 1        Afrique du Sud   2017
# 2               Albanie   2017
# 3               Algérie   2017
# 4             Allemagne   2017
#
# Élément  Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                                                   5.0
# 1                                                 143.0
# 2                                                  85.0
# 3                                                  22.0
# 4                                                  71.0
#
# Élément  Disponibilité alimentaire en quantité (kg/personne/an)  \
# 0                                                     1.53
# 1                                                    35.69
# 2                                                    16.36
# 3                                                     6.38
# 4                                                    19.47
#
# Élément  Disponibilité de matière grasse en quantité (g/personne/jour)  \
# 0                                                     0.33
# 1                                                     9.25
# 2                                                     6.45
# 3                                                     1.50
# 4                                                     4.16
#
# Élément  Disponibilité de protéines en quantité (g/personne/jour)  \
# 0                                                     0.54
# 1                                                    14.11
# 2                                                     6.26
# 3                                                     1.97
# 4                                                     7.96
#
# Élément  Disponibilité intérieure  Exportations - Quantité  \
# 0                            57.0                      NaN
# 1                          2118.0                     63.0
# 2                            47.0                      0.0
# 3                           277.0                      0.0
# 4                          1739.0                    646.0
#
# Élément  Importations - Quantité  Nourriture  Production
# 0                           29.0        55.0        28.0
# 1                          514.0      2035.0      1667.0
# 2                           38.0        47.0        13.0
# 3                            2.0       264.0       275.0
# 4                          842.0      1609.0      1514.0

# %% [markdown]
# # 2. Selection des attributs de nos individus avec l'analyse PESTEL

# %%
# Politique : Stabilité politique générale d'un gouvernement 
# Economie : Evolution du PIB, Niveau de vie des habitants(revenu moyen)
# Sociale : Croissance démographique
# Marché agricole: Production, Dispo Alimentaire, importations, exportations
# Ecologique : Pollution, traitement des déchets (gaspillage), distance entre pays

# %% [markdown]
# ## 2.1 Croissance démographique moyenne <a name="21"></a>

# %%
pop = pd.read_csv("Data Source/Population_2000_2018.csv")

# %%
pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4411 entries, 0 to 4410
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Code Domaine            4411 non-null   object
#  1   Domaine                 4411 non-null   object
#  2   Code zone               4411 non-null   int64
#  3   Zone                    4411 non-null   object
#  4   Code Élément            4411 non-null   int64
#  5   Élément                 4411 non-null   object
#  6   Code Produit            4411 non-null   int64
#  7   Produit                 4411 non-null   object
#  8   Code année              4411 non-null   int64
#  9   Année                   4411 non-null   int64
#  10  Unité                   4411 non-null   object
#  11  Valeur                  4411 non-null   float64
#  12  Symbole                 4411 non-null   object
#  13  Description du Symbole  4411 non-null   object
#  14  Note                    258 non-null    object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 517.0+ KB

# %%
selected_columns=["Zone","Année","Valeur"]
pop = pop[selected_columns]
pop.columns = ["Pays","Année","Population"]

# %%
pop.head(5)
# Out:
#           Pays  Année  Population
# 0  Afghanistan   2000   20779.953
# 1  Afghanistan   2001   21606.988
# 2  Afghanistan   2002   22600.770
# 3  Afghanistan   2003   23680.871
# 4  Afghanistan   2004   24726.684

# %%
pop["Population"]
# Out:
# 0       20779.953
# 1       21606.988
# 2       22600.770
# 3       23680.871
# 4       24726.684
#           ...
# 4406    13586.707
# 4407    13814.629
# 4408    14030.331
# 4409    14236.595
# 4410    14438.802
# Name: Population, Length: 4411, dtype: float64

# %%
pop[pop["Pays"] == "Afghanistan"]["Population"]
# Out:
# 0     20779.953
# 1     21606.988
# 2     22600.770
# 3     23680.871
# 4     24726.684
# 5     25654.277
# 6     26433.049
# 7     27100.536
# 8     27722.276
# 9     28394.813
# 10    29185.507
# 11    30117.413
# 12    31161.376
# 13    32269.589
# 14    33370.794
# 15    34413.603
# 16    35383.032
# 17    36296.113
# 18    37171.921
# Name: Population, dtype: float64

# %%
pop_delta = np.diff(pop[pop["Pays"] == "Afghanistan"]["Population"],prepend=0)

# %%
def demographic_growth(df, pays):
    # Calcul le delta de population d'une année à l'autre pour un pays
    pop_delta = np.diff(df[df["Pays"] == pays]["Population"],prepend=0)
    pop_ref = np.cumsum(pop_delta)
    growth_pop = [0]
    for i in range(1,len(pop_delta)):
        absolute_growth = round((pop_delta[i] / pop_ref[i-1]),3)
        growth_pop.append(absolute_growth)
    return growth_pop

# %%
# Calcul la croissance démographique pour tous les pays
growth_pop = []
for pays in pop["Pays"].unique():
    growth_pop.append(demographic_growth(pop,pays))

# %%
pop["croissance demo"] = np.concatenate(growth_pop)

# %%
pop.head(20)
# Out:
#               Pays  Année  Population  croissance demo
# 0      Afghanistan   2000   20779.953            0.000
# 1      Afghanistan   2001   21606.988            0.040
# 2      Afghanistan   2002   22600.770            0.046
# 3      Afghanistan   2003   23680.871            0.048
# 4      Afghanistan   2004   24726.684            0.044
# 5      Afghanistan   2005   25654.277            0.038
# 6      Afghanistan   2006   26433.049            0.030
# 7      Afghanistan   2007   27100.536            0.025
# 8      Afghanistan   2008   27722.276            0.023
# 9      Afghanistan   2009   28394.813            0.024
# 10     Afghanistan   2010   29185.507            0.028
# 11     Afghanistan   2011   30117.413            0.032
# 12     Afghanistan   2012   31161.376            0.035
# 13     Afghanistan   2013   32269.589            0.036
# 14     Afghanistan   2014   33370.794            0.034
# 15     Afghanistan   2015   34413.603            0.031
# 16     Afghanistan   2016   35383.032            0.028
# 17     Afghanistan   2017   36296.113            0.026
# 18     Afghanistan   2018   37171.921            0.024
# 19  Afrique du Sud   2000   44967.708            0.000

# %% [markdown]
# ### Qualité des données

# %%
# Fonction test sur les valeurs temporelles manquantes pour chaque pays
def time_period_test(df, period_column_name, country_columns_name, data_quality_rate=80):
    
    df = df[[country_columns_name, period_column_name]].drop_duplicates()
    min_period = df.describe()[period_column_name]["min"]
    max_period = df.describe()[period_column_name]["max"]
    period_length = (max_period - min_period) + 1
    print(period_length)
    intervalle_df = df.groupby(by=[country_columns_name]).agg({period_column_name : "count"}).rename(columns={period_column_name : "Intervalle"})["Intervalle"].reset_index()
    intervalle_df["année_inf"] = df.groupby(by=[country_columns_name]).agg({period_column_name : "min"}).reset_index()[period_column_name]
    intervalle_df["année_sup"] = df.groupby(by=[country_columns_name]).agg({period_column_name : "max"}).reset_index()[period_column_name]
    intervalle_df["qualité (%)"] = round(intervalle_df["Intervalle"] / period_length,3)*100
    print("Maximum time period length : {} - {}".format(round(min_period), round(max_period)))
    return intervalle_df.loc[intervalle_df["qualité (%)"] > data_quality_rate, :]

# %%
# Taux d'information sur la periode 2000 - 2018
time_period_test(pop,"Année","Pays")
# Out:
# 19.0
# Maximum time period length : 2000 - 2018
#                           Pays  Intervalle  année_inf  année_sup  qualité (%)
# 0                  Afghanistan          19       2000       2018        100.0
# 1               Afrique du Sud          19       2000       2018        100.0
# 2                      Albanie          19       2000       2018        100.0
# 3                      Algérie          19       2000       2018        100.0
# 4                    Allemagne          19       2000       2018        100.0
# ..                         ...         ...        ...        ...          ...
# 233               Îles Salomon          19       2000       2018        100.0
# 234    Îles Turques-et-Caïques          19       2000       2018        100.0
# 235   Îles Vierges américaines          19       2000       2018        100.0
# 236  Îles Vierges britanniques          19       2000       2018        100.0
# 237      Îles Wallis-et-Futuna          19       2000       2018        100.0
#
# [227 rows x 5 columns]

# %%
# calcul de la croissance démographique moyenne par pays
pop_final = pop.groupby(by=["Pays"], as_index=False).agg({"croissance demo" : "mean"})

# %%
from libraries import country_translate

# %%
pop_final["Country Name"] = country_translate(pop_final["Pays"],"Pays")
pop_final.drop(columns="Pays", inplace=True)

# %% [markdown]
# ## 2.2 Stabilité politique moyenne (2000-2018)

# %%
stab_pol = pd.read_csv("Data Source/PoliticalStability.csv")

# %%
stab_pol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3526 entries, 0 to 3525
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country              3526 non-null   object
#  1   Year                 3526 non-null   int64
#  2   Political_Stability  3526 non-null   float64
#  3   Granularity          3526 non-null   object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 110.3+ KB

# %%
time_period_test(stab_pol, "Year", "Country")
# Out:
# 19.0
# Maximum time period length : 2000 - 2018
#                                 Country  Intervalle  année_inf  année_sup  \
# 0                           Afghanistan          18       2000       2018
# 1                               Albania          18       2000       2018
# 2                               Algeria          18       2000       2018
# 4                               Andorra          18       2000       2018
# 5                                Angola          18       2000       2018
# ..                                  ...         ...        ...        ...
# 195  Venezuela (Bolivarian Republic of)          18       2000       2018
# 196                            Viet Nam          18       2000       2018
# 197                               Yemen          18       2000       2018
# 198                              Zambia          18       2000       2018
# 199                            Zimbabwe          18       2000       2018
#
#      qualité (%)
# 0           94.7
# 1           94.7
# 2           94.7
# 4           94.7
# 5           94.7
# ..           ...
# 195         94.7
# 196         94.7
# 197         94.7
# 198         94.7
# 199         94.7
#
# [194 rows x 5 columns]

# %%
stab_pol.drop(columns=["Granularity"], inplace=True)

# %%
stab_pol_final = stab_pol.groupby(by=["Country"], as_index=False).agg({"Political_Stability" : "mean"})
stab_pol_final.rename(columns={"Country":"Country Name"}, inplace=True)

# %%
stab_pol_final.head(5)
# Out:
#      Country Name  Political_Stability
# 0     Afghanistan            -2.461111
# 1         Albania            -0.080556
# 2         Algeria            -1.216667
# 3  American Samoa             0.980000
# 4         Andorra             1.339444

# %% [markdown]
# ## 2.3 Evolution du PIB moyen (1961 - 2021)

# %%
# Justifier le nombre de cluster
# Normaliser les données

# %%
# Data source : World Bank
pib_mond=pd.read_csv("Data Source/GDP_mondial_growth.csv", header=2)

# %%
pib_mond.dropna(how="all", axis=1, inplace=True)
droped_columns = ["Country Code", "Indicator Name","Indicator Code"]
pib_mond.drop(columns=droped_columns, inplace=True)

# %%
pib_mond_final = pib_mond.melt(id_vars="Country Name", var_name="Année", value_name="GDP_growth (%)")##

# %%
pib_mond_final["Année"] = pd.to_numeric(pib_mond_final["Année"],errors="coerce")
pib_mond_final.dtypes
time_period_test(pib_mond_final,"Année", "Country Name")
# Out:
# 61.0
# Maximum time period length : 1961 - 2021
#                     Country Name  Intervalle  année_inf  année_sup  \
# 0                    Afghanistan          61       1961       2021
# 1    Africa Eastern and Southern          61       1961       2021
# 2     Africa Western and Central          61       1961       2021
# 3                        Albania          61       1961       2021
# 4                        Algeria          61       1961       2021
# ..                           ...         ...        ...        ...
# 261           West Bank and Gaza          61       1961       2021
# 262                        World          61       1961       2021
# 263                  Yemen, Rep.          61       1961       2021
# 264                       Zambia          61       1961       2021
# 265                     Zimbabwe          61       1961       2021
#
#      qualité (%)
# 0          100.0
# 1          100.0
# 2          100.0
# 3          100.0
# 4          100.0
# ..           ...
# 261        100.0
# 262        100.0
# 263        100.0
# 264        100.0
# 265        100.0
#
# [266 rows x 5 columns]

# %%
pib_mond_final = pib_mond_final.groupby(by=["Country Name"], as_index=False).agg({"GDP_growth (%)":"mean"})

# %% [markdown]
# ## 2.4 Les écarts moyen sur le revenu des ménages (1960 - 2021)

# %%
pouv_achat = pd.read_csv("Data Source/Social_critera.csv")

# %%
pouv_achat
# Out:
#                                           Country Name Country Code  \
# 0                                          Afghanistan          AFG
# 1                                          Afghanistan          AFG
# 2                                              Albania          ALB
# 3                                              Albania          ALB
# 4                                              Algeria          DZA
# ..                                                 ...          ...
# 478                                                NaN          NaN
# 479                                                NaN          NaN
# 480                                                NaN          NaN
# 481  Data from database: Environment Social and Gov...          NaN
# 482                           Last Updated: 04/27/2022          NaN
#
#                                            Series Name     Series Code  \
# 0                                           Gini index     SI.POV.GINI
# 1    Annualized average growth rate in per capita r...  SI.SPR.PCAP.ZG
# 2                                           Gini index     SI.POV.GINI
# 3    Annualized average growth rate in per capita r...  SI.SPR.PCAP.ZG
# 4                                           Gini index     SI.POV.GINI
# ..                                                 ...             ...
# 478                                                NaN             NaN
# 479                                                NaN             NaN
# 480                                                NaN             NaN
# 481                                                NaN             NaN
# 482                                                NaN             NaN
#
#     1960 [YR1960] 1961 [YR1961] 1962 [YR1962] 1963 [YR1963] 1964 [YR1964]  \
# 0              ..            ..            ..            ..            ..
# 1              ..            ..            ..            ..            ..
# 2              ..            ..            ..            ..            ..
# 3              ..            ..            ..            ..            ..
# 4              ..            ..            ..            ..            ..
# ..            ...           ...           ...           ...           ...
# 478           NaN           NaN           NaN           NaN           NaN
# 479           NaN           NaN           NaN           NaN           NaN
# 480           NaN           NaN           NaN           NaN           NaN
# 481           NaN           NaN           NaN           NaN           NaN
# 482           NaN           NaN           NaN           NaN           NaN
#
#     1965 [YR1965]  ... 2012 [YR2012] 2013 [YR2013] 2014 [YR2014]  \
# 0              ..  ...            ..            ..            ..
# 1              ..  ...            ..            ..            ..
# 2              ..  ...            29            ..          34.6
# 3              ..  ...            ..            ..            ..
# 4              ..  ...            ..            ..            ..
# ..            ...  ...           ...           ...           ...
# 478           NaN  ...           NaN           NaN           NaN
# 479           NaN  ...           NaN           NaN           NaN
# 480           NaN  ...           NaN           NaN           NaN
# 481           NaN  ...           NaN           NaN           NaN
# 482           NaN  ...           NaN           NaN           NaN
#
#     2015 [YR2015] 2016 [YR2016] 2017 [YR2017] 2018 [YR2018] 2019 [YR2019]  \
# 0              ..            ..            ..            ..            ..
# 1              ..            ..            ..            ..            ..
# 2            32.8          33.7          33.1          30.1          30.8
# 3              ..            ..          6.96            ..            ..
# 4              ..            ..            ..            ..            ..
# ..            ...           ...           ...           ...           ...
# 478           NaN           NaN           NaN           NaN           NaN
# 479           NaN           NaN           NaN           NaN           NaN
# 480           NaN           NaN           NaN           NaN           NaN
# 481           NaN           NaN           NaN           NaN           NaN
# 482           NaN           NaN           NaN           NaN           NaN
#
#     2020 [YR2020] 2021 [YR2021]
# 0              ..            ..
# 1              ..            ..
# 2              ..            ..
# 3              ..            ..
# 4              ..            ..
# ..            ...           ...
# 478           NaN           NaN
# 479           NaN           NaN
# 480           NaN           NaN
# 481           NaN           NaN
# 482           NaN           NaN
#
# [483 rows x 66 columns]

# %%
pouv_achat.replace({".." : np.nan}, inplace = True)

# %%
pouv_achat
# Out:
#                                           Country Name Country Code  \
# 0                                          Afghanistan          AFG
# 1                                          Afghanistan          AFG
# 2                                              Albania          ALB
# 3                                              Albania          ALB
# 4                                              Algeria          DZA
# ..                                                 ...          ...
# 478                                                NaN          NaN
# 479                                                NaN          NaN
# 480                                                NaN          NaN
# 481  Data from database: Environment Social and Gov...          NaN
# 482                           Last Updated: 04/27/2022          NaN
#
#                                            Series Name     Series Code  \
# 0                                           Gini index     SI.POV.GINI
# 1    Annualized average growth rate in per capita r...  SI.SPR.PCAP.ZG
# 2                                           Gini index     SI.POV.GINI
# 3    Annualized average growth rate in per capita r...  SI.SPR.PCAP.ZG
# 4                                           Gini index     SI.POV.GINI
# ..                                                 ...             ...
# 478                                                NaN             NaN
# 479                                                NaN             NaN
# 480                                                NaN             NaN
# 481                                                NaN             NaN
# 482                                                NaN             NaN
#
#      1960 [YR1960]  1961 [YR1961]  1962 [YR1962]  1963 [YR1963]  \
# 0              NaN            NaN            NaN            NaN
# 1              NaN            NaN            NaN            NaN
# 2              NaN            NaN            NaN            NaN
# 3              NaN            NaN            NaN            NaN
# 4              NaN            NaN            NaN            NaN
# ..             ...            ...            ...            ...
# 478            NaN            NaN            NaN            NaN
# 479            NaN            NaN            NaN            NaN
# 480            NaN            NaN            NaN            NaN
# 481            NaN            NaN            NaN            NaN
# 482            NaN            NaN            NaN            NaN
#
#      1964 [YR1964]  1965 [YR1965]  ...  2012 [YR2012] 2013 [YR2013]  \
# 0              NaN            NaN  ...            NaN           NaN
# 1              NaN            NaN  ...            NaN           NaN
# 2              NaN            NaN  ...             29           NaN
# 3              NaN            NaN  ...            NaN           NaN
# 4              NaN            NaN  ...            NaN           NaN
# ..             ...            ...  ...            ...           ...
# 478            NaN            NaN  ...            NaN           NaN
# 479            NaN            NaN  ...            NaN           NaN
# 480            NaN            NaN  ...            NaN           NaN
# 481            NaN            NaN  ...            NaN           NaN
# 482            NaN            NaN  ...            NaN           NaN
#
#      2014 [YR2014] 2015 [YR2015]  2016 [YR2016] 2017 [YR2017]  2018 [YR2018]  \
# 0              NaN           NaN            NaN           NaN            NaN
# 1              NaN           NaN            NaN           NaN            NaN
# 2             34.6          32.8           33.7          33.1           30.1
# 3              NaN           NaN            NaN          6.96            NaN
# 4              NaN           NaN            NaN           NaN            NaN
# ..             ...           ...            ...           ...            ...
# 478            NaN           NaN            NaN           NaN            NaN
# 479            NaN           NaN            NaN           NaN            NaN
# 480            NaN           NaN            NaN           NaN            NaN
# 481            NaN           NaN            NaN           NaN            NaN
# 482            NaN           NaN            NaN           NaN            NaN
#
#      2019 [YR2019] 2020 [YR2020] 2021 [YR2021]
# 0              NaN           NaN           NaN
# 1              NaN           NaN           NaN
# 2             30.8           NaN           NaN
# 3              NaN           NaN           NaN
# 4              NaN           NaN           NaN
# ..             ...           ...           ...
# 478            NaN           NaN           NaN
# 479            NaN           NaN           NaN
# 480            NaN           NaN           NaN
# 481            NaN           NaN           NaN
# 482            NaN           NaN           NaN
#
# [483 rows x 66 columns]

# %%
pouv_achat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 483 entries, 0 to 482
# Data columns (total 66 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   480 non-null    object
#  1   Country Code   478 non-null    object
#  2   Series Name    478 non-null    object
#  3   Series Code    478 non-null    object
#  4   1960 [YR1960]  0 non-null      float64
#  5   1961 [YR1961]  0 non-null      float64
#  6   1962 [YR1962]  0 non-null      float64
#  7   1963 [YR1963]  0 non-null      float64
#  8   1964 [YR1964]  0 non-null      float64
#  9   1965 [YR1965]  0 non-null      float64
#  10  1966 [YR1966]  0 non-null      float64
#  11  1967 [YR1967]  1 non-null      object
#  12  1968 [YR1968]  0 non-null      float64
#  13  1969 [YR1969]  1 non-null      object
#  14  1970 [YR1970]  0 non-null      float64
#  15  1971 [YR1971]  1 non-null      object
#  16  1972 [YR1972]  0 non-null      float64
#  17  1973 [YR1973]  0 non-null      float64
#  18  1974 [YR1974]  2 non-null      object
#  19  1975 [YR1975]  2 non-null      object
#  20  1976 [YR1976]  0 non-null      float64
#  21  1977 [YR1977]  1 non-null      object
#  22  1978 [YR1978]  1 non-null      object
#  23  1979 [YR1979]  5 non-null      object
#  24  1980 [YR1980]  3 non-null      object
#  25  1981 [YR1981]  7 non-null      object
#  26  1982 [YR1982]  2 non-null      object
#  27  1983 [YR1983]  4 non-null      object
#  28  1984 [YR1984]  5 non-null      object
#  29  1985 [YR1985]  11 non-null     object
#  30  1986 [YR1986]  14 non-null     object
#  31  1987 [YR1987]  20 non-null     object
#  32  1988 [YR1988]  9 non-null      object
#  33  1989 [YR1989]  13 non-null     object
#  34  1990 [YR1990]  17 non-null     object
#  35  1991 [YR1991]  19 non-null     object
#  36  1992 [YR1992]  31 non-null     object
#  37  1993 [YR1993]  22 non-null     object
#  38  1994 [YR1994]  26 non-null     object
#  39  1995 [YR1995]  36 non-null     object
#  40  1996 [YR1996]  31 non-null     object
#  41  1997 [YR1997]  27 non-null     object
#  42  1998 [YR1998]  36 non-null     object
#  43  1999 [YR1999]  31 non-null     object
#  44  2000 [YR2000]  48 non-null     object
#  45  2001 [YR2001]  34 non-null     object
#  46  2002 [YR2002]  52 non-null     object
#  47  2003 [YR2003]  57 non-null     object
#  48  2004 [YR2004]  68 non-null     object
#  49  2005 [YR2005]  72 non-null     object
#  50  2006 [YR2006]  73 non-null     object
#  51  2007 [YR2007]  68 non-null     object
#  52  2008 [YR2008]  73 non-null     object
#  53  2009 [YR2009]  76 non-null     object
#  54  2010 [YR2010]  83 non-null     object
#  55  2011 [YR2011]  78 non-null     object
#  56  2012 [YR2012]  86 non-null     object
#  57  2013 [YR2013]  76 non-null     object
#  58  2014 [YR2014]  89 non-null     object
#  59  2015 [YR2015]  94 non-null     object
#  60  2016 [YR2016]  87 non-null     object
#  61  2017 [YR2017]  85 non-null     object
#  62  2018 [YR2018]  104 non-null    object
#  63  2019 [YR2019]  96 non-null     object
#  64  2020 [YR2020]  32 non-null     object
#  65  2021 [YR2021]  1 non-null      object
# dtypes: float64(12), object(54)
# memory usage: 249.2+ KB

# %%
# Renomer les colonnes années :
mapper = {x : x.split(" ")[0] for x in pouv_achat.columns.values[4:]}
pouv_achat.rename(columns=mapper, inplace=True)

# %%
pouv_achat["Series Name"].value_counts()
# Out:
# Gini index                                                                                                   239
# Annualized average growth rate in per capita real survey mean consumption or income, total population (%)    239
# Name: Series Name, dtype: int64

# %%
indice_gini = pouv_achat[pouv_achat["Series Name"] == "Gini index"].copy()
indice_gini.reset_index(drop=True, inplace=True)

# %%
# Suppression des colonnes qui ne seront pas "unpivot"
indice_gini.drop(columns=["Country Code","Series Name","Series Code"], inplace=True)

# %%
indice_gini
# Out:
#                                    Country Name  1960  1961  1962  1963  1964  \
# 0                                   Afghanistan   NaN   NaN   NaN   NaN   NaN
# 1                                       Albania   NaN   NaN   NaN   NaN   NaN
# 2                                       Algeria   NaN   NaN   NaN   NaN   NaN
# 3                                       Andorra   NaN   NaN   NaN   NaN   NaN
# 4                                        Angola   NaN   NaN   NaN   NaN   NaN
# ..                                          ...   ...   ...   ...   ...   ...
# 234      Latin America & Caribbean (IDA & IBRD)   NaN   NaN   NaN   NaN   NaN
# 235     Middle East & North Africa (IDA & IBRD)   NaN   NaN   NaN   NaN   NaN
# 236                     South Asia (IDA & IBRD)   NaN   NaN   NaN   NaN   NaN
# 237  Sub-Saharan Africa (excluding high income)   NaN   NaN   NaN   NaN   NaN
# 238             Sub-Saharan Africa (IDA & IBRD)   NaN   NaN   NaN   NaN   NaN
#
#      1965  1966 1967  1968  ... 2012  2013  2014  2015  2016  2017  2018  \
# 0     NaN   NaN  NaN   NaN  ...  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1     NaN   NaN  NaN   NaN  ...   29   NaN  34.6  32.8  33.7  33.1  30.1
# 2     NaN   NaN  NaN   NaN  ...  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3     NaN   NaN  NaN   NaN  ...  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4     NaN   NaN  NaN   NaN  ...  NaN   NaN   NaN   NaN   NaN   NaN  51.3
# ..    ...   ...  ...   ...  ...  ...   ...   ...   ...   ...   ...   ...
# 234   NaN   NaN  NaN   NaN  ...  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 235   NaN   NaN  NaN   NaN  ...  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 236   NaN   NaN  NaN   NaN  ...  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 237   NaN   NaN  NaN   NaN  ...  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 238   NaN   NaN  NaN   NaN  ...  NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      2019 2020 2021
# 0     NaN  NaN  NaN
# 1    30.8  NaN  NaN
# 2     NaN  NaN  NaN
# 3     NaN  NaN  NaN
# 4     NaN  NaN  NaN
# ..    ...  ...  ...
# 234   NaN  NaN  NaN
# 235   NaN  NaN  NaN
# 236   NaN  NaN  NaN
# 237   NaN  NaN  NaN
# 238   NaN  NaN  NaN
#
# [239 rows x 63 columns]

# %%
indice_gini.isna().sum()
# Out:
# Country Name      0
# 1960            239
# 1961            239
# 1962            239
# 1963            239
#                ...
# 2017            164
# 2018            155
# 2019            181
# 2020            220
# 2021            238
# Length: 63, dtype: int64

# %%
indice_gini_unpivot = indice_gini.melt(id_vars="Country Name", value_name="gini index", var_name="Année")
indice_gini_unpivot["gini index"] = pd.to_numeric(indice_gini_unpivot["gini index"])

# %%
indice_gini_final = indice_gini_unpivot.groupby(by=["Country Name"], as_index=False).agg({"gini index" : "mean"})

# %%
indice_gini_final
# Out:
#     Country Name  gini index
# 0    Afghanistan         NaN
# 1        Albania   31.218182
# 2        Algeria   34.366667
# 3        Andorra         NaN
# 4         Angola   48.666667
# ..           ...         ...
# 234      Vietnam   36.090909
# 235        World         NaN
# 236  Yemen, Rep.   35.466667
# 237       Zambia   52.688889
# 238     Zimbabwe   45.933333
#
# [239 rows x 2 columns]

# %%
indice_gini_final.sort_values('gini index', ascending=False).head(20)
# Out:
#                  Country Name  gini index
# 196              South Africa   61.883333
# 152                   Namibia   61.133333
# 34   Central African Republic   58.750000
# 23                   Botswana   58.700000
# 209                  Suriname   57.900000
# 18                     Belize   57.733333
# 24                     Brazil   56.522222
# 81                  Guatemala   55.000000
# 63                   Eswatini   54.925000
# 121                   Lesotho   53.925000
# 88                   Honduras   53.906667
# 39                   Colombia   53.840909
# 169                    Panama   53.629630
# 237                    Zambia   52.688889
# 21                    Bolivia   51.038095
# 37                      Chile   50.606667
# 157                 Nicaragua   50.600000
# 40                    Comoros   50.600000
# 171                  Paraguay   50.562500
# 150                Mozambique   50.050000

# %% [markdown]
# ## 2.5 Les emissions de CO2 (1960 - 2018)

# %%
CO2_emis = pd.read_csv("Data Source/CO2_worldly_emission.csv", header=2)

# %%
CO2_emis.drop(columns=["Unnamed: 66", "Country Code","Indicator Name","Indicator Code"], inplace=True)

# %%
CO2_emis
# Out:
#                     Country Name  1960  1961  1962  1963  1964  1965  1966  \
# 0                          Aruba   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1    Africa Eastern and Southern   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2                    Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3     Africa Western and Central   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4                         Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..                           ...   ...   ...   ...   ...   ...   ...   ...
# 261                       Kosovo   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 262                  Yemen, Rep.   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 263                 South Africa   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 264                       Zambia   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 265                     Zimbabwe   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      1967  1968  ...      2012      2013      2014      2015      2016  \
# 0     NaN   NaN  ...       NaN       NaN       NaN       NaN       NaN
# 1     NaN   NaN  ...  0.992616  1.005027  1.016649  0.966589  0.948410
# 2     NaN   NaN  ...  0.259295  0.185624  0.146236  0.172897  0.149789
# 3     NaN   NaN  ...  0.480603  0.508099  0.515960  0.494065  0.499405
# 4     NaN   NaN  ...  0.950696  1.036294  1.099779  1.135044  1.031811
# ..    ...   ...  ...       ...       ...       ...       ...       ...
# 261   NaN   NaN  ...       NaN       NaN       NaN       NaN       NaN
# 262   NaN   NaN  ...  0.858491  1.106688  1.062211  0.511362  0.399364
# 263   NaN   NaN  ...  8.077958  8.138264  8.212241  7.669938  7.563739
# 264   NaN   NaN  ...  0.278601  0.284058  0.304550  0.312355  0.325115
# 265   NaN   NaN  ...  0.915735  0.919824  0.889104  0.899770  0.785441
#
#          2017      2018      2019  2020  2021
# 0         NaN       NaN       NaN   NaN   NaN
# 1    0.937926  0.917507  0.913618   NaN   NaN
# 2    0.131695  0.163295  0.159824   NaN   NaN
# 3    0.483140  0.486456  0.493923   NaN   NaN
# 4    0.813301  0.777675  0.792137   NaN   NaN
# ..        ...       ...       ...   ...   ...
# 261       NaN       NaN       NaN   NaN   NaN
# 262  0.359622  0.341068  0.380633   NaN   NaN
# 263  7.641675  7.515679  7.507736   NaN   NaN
# 264  0.404068  0.445489  0.380717   NaN   NaN
# 265  0.726297  0.857411  0.802979   NaN   NaN
#
# [266 rows x 63 columns]

# %%
CO2_emis_unpivot = CO2_emis.melt(id_vars="Country Name", var_name="Année", value_name="CO2 emission (ton/capita)")

# %%
CO2_emis_final = CO2_emis_unpivot.groupby(by=["Country Name"], as_index=False).agg({"CO2 emission (ton/capita)" : "mean"})
CO2_emis_final.head(5)
# Out:
#                   Country Name  CO2 emission (ton/capita)
# 0                  Afghanistan                   0.116895
# 1  Africa Eastern and Southern                   0.968398
# 2   Africa Western and Central                   0.501364
# 3                      Albania                   1.250816
# 4                      Algeria                   3.021488

# %% [markdown]
# ## 2.6 Les décès liés à la sous-nutrition (1960 - 2021)

# %%
sous_nut = pd.read_csv("Data Source/Death_nutrition_cause.csv", header=0)

# %%
sous_nut.drop(columns=["Series Name","Series Code","Country Code"], inplace=True)
sous_nut.replace({"..": np.nan}, inplace=True)
sous_nut.dropna(how="all", inplace=True)

# %%
mapper = {x : x.split(" ")[0] for x in sous_nut.columns.values}
sous_nut.rename(columns=mapper, inplace=True)

# %%
sous_nut
# Out:
#                          Country  1960  1961  1962  1963  1964  1965  1966  \
# 0                    Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1    Africa Eastern and Southern   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2     Africa Western and Central   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3                        Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4                        Algeria   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..                           ...   ...   ...   ...   ...   ...   ...   ...
# 261           West Bank and Gaza   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 262                        World   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 263                  Yemen, Rep.   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 264                       Zambia   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 265                     Zimbabwe   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      1967  1968  ...  2012  2013  2014              2015  2016  2017  2018  \
# 0     NaN   NaN  ...   NaN   NaN   NaN  39.3909806318543   NaN   NaN   NaN
# 1     NaN   NaN  ...   NaN   NaN   NaN   52.911433522748   NaN   NaN   NaN
# 2     NaN   NaN  ...   NaN   NaN   NaN  61.8831660993608   NaN   NaN   NaN
# 3     NaN   NaN  ...   NaN   NaN   NaN  2.95538161966608   NaN   NaN   NaN
# 4     NaN   NaN  ...   NaN   NaN   NaN  14.7662314046474   NaN   NaN   NaN
# ..    ...   ...  ...   ...   ...   ...               ...   ...   ...   ...
# 261   NaN   NaN  ...   NaN   NaN   NaN               NaN   NaN   NaN   NaN
# 262   NaN   NaN  ...   NaN   NaN   NaN  20.4760640119937   NaN   NaN   NaN
# 263   NaN   NaN  ...   NaN   NaN   NaN  32.1041669604299   NaN   NaN   NaN
# 264   NaN   NaN  ...   NaN   NaN   NaN  58.3146068008607   NaN   NaN   NaN
# 265   NaN   NaN  ...   NaN   NaN   NaN  51.2479086872291   NaN   NaN   NaN
#
#                  2019  2020  2021
# 0    32.9304513537869   NaN   NaN
# 1    49.0198435796198   NaN   NaN
# 2    59.5038196263206   NaN   NaN
# 3     3.0231082827299   NaN   NaN
# 4    12.9844112787695   NaN   NaN
# ..                ...   ...   ...
# 261               NaN   NaN   NaN
# 262  18.4088503755545   NaN   NaN
# 263   30.145592705535   NaN   NaN
# 264   56.517852657474   NaN   NaN
# 265  47.6473006196949   NaN   NaN
#
# [266 rows x 63 columns]

# %%
sous_nut_melt = sous_nut.melt(id_vars="Country", value_name="unurished death cause (%)", var_name="Année")

# %%
sous_nut_melt["unurished death cause (%)"] = pd.to_numeric(sous_nut_melt["unurished death cause (%)"])

# %%
sous_nut_final = sous_nut_melt[["Country","unurished death cause (%)"]].groupby(by=["Country"]).agg({"unurished death cause (%)" : "mean"})

# %%
sous_nut_final.rename_axis(axis=0, index="Country Name", inplace=True)

# %% [markdown]
# ## 2.7 Importation, exportation, production et disponibilité intérieure

# %%
attributs = ["Zone","Disponibilité intérieure","Exportations - Quantité","Importations - Quantité","Production"]
volaille_data_final = volaille_data[attributs]

# %%
volaille_data_final["Zone"] = country_translate(volaille_data_final["Zone"], "Zone")
volaille_data_final.rename(columns={"Zone":"Country Name"}, inplace=True)
# Out:
# /var/folders/s6/gkzq10vd69gbt7bn1j6wv3mc0000gn/T/ipykernel_14692/3993024191.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   volaille_data_final["Zone"] = country_translate(volaille_data_final["Zone"], "Zone")
# /var/folders/s6/gkzq10vd69gbt7bn1j6wv3mc0000gn/T/ipykernel_14692/3993024191.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   volaille_data_final.rename(columns={"Zone":"Country Name"}, inplace=True)

# %%
volaille_data_final.head(5)
# Out:
# Élément  Country Name  Disponibilité intérieure  Exportations - Quantité  \
# 0         Afghanistan                      57.0                      NaN
# 1        South Africa                    2118.0                     63.0
# 2             Albania                      47.0                      0.0
# 3             Algeria                     277.0                      0.0
# 4             Germany                    1739.0                    646.0
#
# Élément  Importations - Quantité  Production
# 0                           29.0        28.0
# 1                          514.0      1667.0
# 2                           38.0        13.0
# 3                            2.0       275.0
# 4                          842.0      1514.0

# %% [markdown]
# # 3 ACP

# %% [markdown]
# ## 3.1 Jeu de données

# %%
volaille_data_final.head(5)
# Out:
# Élément  Country Name  Disponibilité intérieure  Exportations - Quantité  \
# 0         Afghanistan                      57.0                      NaN
# 1        South Africa                    2118.0                     63.0
# 2             Albania                      47.0                      0.0
# 3             Algeria                     277.0                      0.0
# 4             Germany                    1739.0                    646.0
#
# Élément  Importations - Quantité  Production
# 0                           29.0        28.0
# 1                          514.0      1667.0
# 2                           38.0        13.0
# 3                            2.0       275.0
# 4                          842.0      1514.0

# %%
pop_final.set_index("Country Name", inplace=True)

# %%
# Jointure entre toutes les tables créées précédemments
data_set = pop_final.join(volaille_data_final.set_index("Country Name"),
               how="inner").join(sous_nut_final,
                                 how="inner").join(CO2_emis_final.set_index("Country Name"),
                                                   how="inner").join(pib_mond_final.set_index("Country Name"),
                                                                    how="inner").join(stab_pol_final.set_index("Country Name"),
                                                                                     how="inner")

# %%
data_set
# Out:
#                       croissance demo  Disponibilité intérieure  \
# Country Name
# Afghanistan                  0.031158                      57.0
# South Africa                 0.013211                    2118.0
# Albania                     -0.004316                      47.0
# Algeria                      0.016368                     277.0
# Germany                      0.001000                    1739.0
# ...                               ...                       ...
# Zimbabwe                     0.010421                      76.0
# United Arab Emirates         0.062263                     412.0
# Ecuador                      0.015842                     341.0
# Ethiopia                     0.026737                      14.0
# Solomon Islands              0.024474                       3.0
#
#                       Exportations - Quantité  Importations - Quantité  \
# Country Name
# Afghanistan                               NaN                     29.0
# South Africa                             63.0                    514.0
# Albania                                   0.0                     38.0
# Algeria                                   0.0                      2.0
# Germany                                 646.0                    842.0
# ...                                       ...                      ...
# Zimbabwe                                  NaN                      6.0
# United Arab Emirates                     94.0                    433.0
# Ecuador                                   0.0                      0.0
# Ethiopia                                  NaN                      1.0
# Solomon Islands                           0.0                      6.0
#
#                       Production  unurished death cause (%)  \
# Country Name
# Afghanistan                 28.0                  45.071499
# South Africa              1667.0                  42.427386
# Albania                     13.0                   4.336743
# Algeria                    275.0                  15.782289
# Germany                   1514.0                   4.602917
# ...                          ...                        ...
# Zimbabwe                    69.0                  59.878604
# United Arab Emirates        48.0                   7.902506
# Ecuador                    340.0                  15.858785
# Ethiopia                    14.0                  54.956260
# Solomon Islands              0.0                  29.371109
#
#                       CO2 emission (ton/capita)  GDP_growth (%)  \
# Country Name
# Afghanistan                            0.116895        6.163893
# South Africa                           7.314787        2.826681
# Albania                                1.250816        2.925658
# Algeria                                3.021488        3.552981
# Germany                                9.940892        1.856720
# ...                                         ...             ...
# Zimbabwe                               1.049610        2.840845
# United Arab Emirates                  25.056277        4.616374
# Ecuador                                2.064149        3.599579
# Ethiopia                               0.078633        5.898699
# Solomon Islands                        0.591476        2.550674
#
#                       Political_Stability
# Country Name
# Afghanistan                     -2.461111
# South Africa                    -0.112222
# Albania                         -0.080556
# Algeria                         -1.216667
# Germany                          0.850556
# ...                                   ...
# Zimbabwe                        -0.983333
# United Arab Emirates             0.832778
# Ecuador                         -0.522222
# Ethiopia                        -1.504444
# Solomon Islands                  0.176667
#
# [128 rows x 9 columns]

# %%
data_set.reset_index().to_csv("Data set/acp_training_set.csv")

# %% [markdown]
# ## 3.2 Calcul des valeurs propres et choix des axes de projection
